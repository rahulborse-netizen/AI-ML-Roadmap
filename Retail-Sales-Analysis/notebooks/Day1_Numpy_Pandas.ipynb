# %%
import numpy as np

sales = np.array([120, 250, 310, 180, 500])

print("Mean:", np.mean(sales))
print("Max:", np.max(sales))
print("Min:", np.min(sales))
print("Sum:", np.sum(sales))
# Out:
# Mean: 272.0
# Max: 500
# Min: 120
# Sum: 1360

# %%
import pandas as pd

data = {
    "Product": ["Laptop","Phone","Tablet","Monitor","Keyboard"],
    "Sales": [1200,900,500,300,150]
}

df = pd.DataFrame(data)

df
# Out:
#     Product  Sales
# 0    Laptop   1200
# 1     Phone    900
# 2    Tablet    500
# 3   Monitor    300
# 4  Keyboard    150

# %%
git add .
git commit -m "Day 1 completed - NumPy and Pandas"
git push origin main
# Out:
#   Cell In[3], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax
